# %% [markdown]
# ## Importing the necessary libraries

# %%
import os
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.image import imread
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, save_model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, BatchNormalization, Flatten, Dropout
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.applications.resnet import ResNet101, preprocess_input
from tensorflow.keras.optimizers import Adam 
from tensorflow.keras.preprocessing import image

# %% [markdown]
# ## Getting the path of the training and testing data of the brain tumor dataset

# %%
dataset_directory_location = 'brain_dataset'

# %%
os.listdir(dataset_directory_location)
# Out:
# ['test', 'train']

# %%
train_dataset_location = os.path.join(dataset_directory_location, 'train')
test_dataset_location = os.path.join(dataset_directory_location, 'test')

# %%
os.listdir(train_dataset_location)
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
os.listdir(test_dataset_location)
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %% [markdown]
# ## Viewing a brain image

# %%
brain_img_glicoma = os.path.join(train_dataset_location, 'glioma')

# %%
os.listdir(brain_img_glicoma)[:1]
# Out:
# ['Tr-gl_0010.jpg']

# %%
brain_img_glicoma_read = imread(os.path.join(brain_img_glicoma, 'Tr-gl_0010.jpg'))

# %%
plt.imshow(brain_img_glicoma_read)

# %%
brain_img_glicoma_read.shape
# Out:
# (512, 512, 3)

# %% [markdown]
# ## Defining the correct shape of the image

# %%
correct_image_shape = (224, 224, 3)

# %% [markdown]
# ## Defining the ImageGenerator and performing Data Augmentation

# %%
image_gen = ImageDataGenerator(rotation_range=20, 
                               width_shift_range=0.1, 
                               height_shift_range=0.1, 
                               shear_range=0.1, 
                               zoom_range=0.1, 
                               horizontal_flip=True, 
                               fill_mode='nearest',
                               preprocessing_function=preprocess_input)

# %%
train_image_gen = image_gen.flow_from_directory(train_dataset_location, 
                                                target_size=correct_image_shape[:2], 
                                                color_mode='rgb', 
                                                batch_size=16, 
                                                class_mode='categorical')

test_image_gen = image_gen.flow_from_directory(test_dataset_location, 
                                                target_size=correct_image_shape[:2], 
                                                color_mode='rgb', 
                                                batch_size=16, 
                                                class_mode='categorical')
# Out:
# Found 5200 images belonging to 4 classes.
# Found 1200 images belonging to 4 classes.

# %% [markdown]
# ## Defining the early stop

# %%
early_stop_loss = EarlyStopping(monitor='loss', patience=2)
early_stop_val_loss = EarlyStopping(monitor='val_loss', patience=2)

# %% [markdown]
# ## Creating and training the model

# %%
model = Sequential()

# %%
resnet101_model = ResNet101(weights='imagenet', include_top=False, input_shape=correct_image_shape)

# %%
resnet101_model.trainable = False

# %%
model.add(resnet101_model)

model.add(Flatten())

model.add(BatchNormalization())

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())

model.add(Dropout(0.3))

model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())

model.add(Dropout(0.3))

model.add(Dense(4, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet101 (Functional)      (None, 7, 7, 2048)        42658176
#
#  flatten (Flatten)           (None, 100352)            0
#
#  batch_normalization (BatchN  (None, 100352)           401408
#  ormalization)
#
#  dense (Dense)               (None, 128)               12845184
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 32)                4128
#
#  batch_normalization_2 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 55,909,668
# Trainable params: 13,050,468
# Non-trainable params: 42,859,200
# _________________________________________________________________

# %%
model.compile(loss=CategoricalCrossentropy(), optimizer=Adam(learning_rate=0.00001), metrics=['accuracy'])

# %%
model.fit(train_image_gen, validation_data=test_image_gen, epochs=30, callbacks=[early_stop_loss, early_stop_val_loss])
# Out:
# Epoch 1/30
# 325/325 [==============================] - 135s 355ms/step - loss: 0.9448 - accuracy: 0.6608 - val_loss: 0.6683 - val_accuracy: 0.7850
# Epoch 2/30
# 325/325 [==============================] - 95s 293ms/step - loss: 0.6267 - accuracy: 0.7762 - val_loss: 0.5318 - val_accuracy: 0.8208
# Epoch 3/30
# 325/325 [==============================] - 93s 286ms/step - loss: 0.5329 - accuracy: 0.8054 - val_loss: 0.4662 - val_accuracy: 0.8300
# Epoch 4/30
# 325/325 [==============================] - 101s 310ms/step - loss: 0.5003 - accuracy: 0.8150 - val_loss: 0.4113 - val_accuracy: 0.8508
# Epoch 5/30
# 325/325 [==============================] - 119s 367ms/step - loss: 0.4424 - accuracy: 0.8408 - val_loss: 0.3489 - val_accuracy: 0.8608
# Epoch 6/30
# 325/325 [==============================] - 97s 297ms/step - loss: 0.4071 - accuracy: 0.8500 - val_loss: 0.3430 - val_accuracy: 0.8675
# Epoch 7/30
# 325/325 [==============================] - 92s 283ms/step - loss: 0.3943 - accuracy: 0.8581 - val_loss: 0.3243 - val_accuracy: 0.8817
# Epoch 8/30
# 325/325 [==============================] - 92s 283ms/step - loss: 0.3782 - accuracy: 0.8665 - val_loss: 0.3019 - val_accuracy: 0.8842
# Epoch 9/30
# 325/325 [==============================] - 94s 288ms/step - loss: 0.3773 - accuracy: 0.8642 - val_loss: 0.2813 - val_accuracy: 0.8967
# Epoch 10/30
# 325/325 [==============================] - 92s 283ms/step - loss: 0.3530 - accuracy: 0.8717 - val_loss: 0.2482 - val_accuracy: 0.9092
# Epoch 11/30
# 325/325 [==============================] - 92s 283ms/step - loss: 0.3355 - accuracy: 0.8738 - val_loss: 0.2631 - val_accuracy: 0.9117
# Epoch 12/30
# 325/325 [==============================] - 93s 287ms/step - loss: 0.3257 - accuracy: 0.8831 - val_loss: 0.2385 - val_accuracy: 0.9158
# Epoch 13/30
# 325/325 [==============================] - 94s 290ms/step - loss: 0.3247 - accuracy: 0.8844 - val_loss: 0.2317 - val_accuracy: 0.9192
# Epoch 14/30
# 325/325 [==============================] - 92s 282ms/step - loss: 0.3066 - accuracy: 0.8856 - val_loss: 0.2180 - val_accuracy: 0.9225
# Epoch 15/30
# 325/325 [==============================] - 93s 287ms/step - loss: 0.2931 - accuracy: 0.8933 - val_loss: 0.2141 - val_accuracy: 0.9242
# Epoch 16/30
# 325/325 [==============================] - 92s 284ms/step - loss: 0.2977 - accuracy: 0.8910 - val_loss: 0.2240 - val_accuracy: 0.9217
# Epoch 17/30
# 325/325 [==============================] - 92s 283ms/step - loss: 0.2798 - accuracy: 0.8988 - val_loss: 0.2202 - val_accuracy: 0.9225

# %%
history_df = pd.DataFrame(model.history.history)

# %%
history_df[['loss', 'val_loss']].plot()
# Out:
# <Axes: >

# %%
history_df[['accuracy', 'val_accuracy']].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Evaluating the model

# %%
model.evaluate(train_image_gen)[1]
# Out:
# 325/325 [==============================] - 76s 232ms/step - loss: 0.1287 - accuracy: 0.9596
# 0.9596154093742371

# %%
model.evaluate(test_image_gen)[1]
# Out:
# 75/75 [==============================] - 17s 228ms/step - loss: 0.2071 - accuracy: 0.9275
# 0.9275000095367432

# %% [markdown]
# ## Predicting on a sample image

# %%
sample_img_load = image.load_img('./brain_dataset/test/pituitary/Te-piTr_0003.jpg', target_size=correct_image_shape)

# %%
sample_img_load
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
sample_img_to_arr = image.img_to_array(sample_img_load)

# %%
sample_img_to_arr = preprocess_input(sample_img_to_arr)

# %%
sample_img_to_arr_expand_dim = np.expand_dims(sample_img_to_arr, 0)

# %%
prediction = model.predict(sample_img_to_arr_expand_dim)[0]
# Out:
# 1/1 [==============================] - 4s 4s/step

# %%
pred_result = np.argmax(prediction)

# %%
class_names = ['glioma', 'meningioma', 'no tumor', 'pituitary']

# %%
pred_final_result = class_names[pred_result]

# %%
pred_final_result
# Out:
# 'pituitary'

# %% [markdown]
# ## Saving the model

# %%
save_model(model, 'resnet101_model')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 104). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: resnet101_model\assets
# INFO:tensorflow:Assets written to: resnet101_model\assets
