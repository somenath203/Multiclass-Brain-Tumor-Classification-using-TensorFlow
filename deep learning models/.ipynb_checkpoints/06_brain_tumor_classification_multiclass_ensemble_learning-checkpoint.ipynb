# %% [markdown]
# ## Importing the necessary libraries

# %%
import os
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.image import imread
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import BatchNormalization, Dense, Flatten, Dropout, Input, Average
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input
from tensorflow.keras.optimizers import Adam 
from tensorflow.keras.preprocessing import image

# %% [markdown]
# ## Getting the path of the training and testing data of the brain tumor dataset

# %%
dataset_directory_location = 'brain_dataset'

# %%
os.listdir(dataset_directory_location)
# Out:
# ['test', 'train']

# %%
train_dataset_location = os.path.join(dataset_directory_location, 'train')
test_dataset_location = os.path.join(dataset_directory_location, 'test')

# %%
os.listdir(train_dataset_location)
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
os.listdir(test_dataset_location)
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %% [markdown]
# ## Viewing a brain image

# %%
brain_img_glicoma = os.path.join(train_dataset_location, 'glioma')

# %%
os.listdir(brain_img_glicoma)[:1]
# Out:
# ['Tr-gl_0010.jpg']

# %%
brain_img_glicoma_read = imread(os.path.join(brain_img_glicoma, 'Tr-gl_0010.jpg'))

# %%
plt.imshow(brain_img_glicoma_read)

# %%
brain_img_glicoma_read.shape
# Out:
# (512, 512, 3)

# %% [markdown]
# ## Defining the correct shape of the image

# %%
correct_image_shape = (224, 224, 3)

# %% [markdown]
# ## Defining the ImageGenerator and performing Data Augmentation

# %%
image_gen = ImageDataGenerator(rotation_range=20, 
                               width_shift_range=0.1, 
                               height_shift_range=0.1, 
                               shear_range=0.1, 
                               zoom_range=0.1, 
                               horizontal_flip=True, 
                               fill_mode='nearest',
                               preprocessing_function=preprocess_input)

# %%
train_image_gen = image_gen.flow_from_directory(train_dataset_location, 
                                                target_size=correct_image_shape[:2], 
                                                color_mode='rgb', 
                                                batch_size=16, 
                                                class_mode='categorical')

test_image_gen = image_gen.flow_from_directory(test_dataset_location, 
                                                target_size=correct_image_shape[:2], 
                                                color_mode='rgb', 
                                                batch_size=16, 
                                                class_mode='categorical')
# Out:
# Found 5200 images belonging to 4 classes.
# Found 1200 images belonging to 4 classes.

# %% [markdown]
# ## Defining the early stop

# %%
early_stop_loss = EarlyStopping(monitor='loss', patience=2)
early_stop_val_loss = EarlyStopping(monitor='val_loss', patience=2)

# %% [markdown]
# ## Creating and training the model

# %%
vgg19_model = load_model('vgg19_model.h5', compile=False)
cnnfromscratch_model = load_model('cnnfromscratch_model.h5', compile=False)

# %%
vgg19_model._name = 'model1'
cnnfromscratch_model._name = 'model2'

# %%
models = [vgg19_model, cnnfromscratch_model]

# %%
model_input = Input(shape=correct_image_shape)

# %%
model_output = [model(model_input) for model in models]

# %%
x = Average()(model_output)

x = BatchNormalization()(x)

x = Dense(128, activation='relu')(x)
x = BatchNormalization()(x)

x = Dropout(0.3)(x)

x = Dense(32, activation='relu')(x)
x = BatchNormalization()(x)

x = Dropout(0.3)(x)

output_of_the_model = Dense(4, activation='softmax')(x)

# %%
ensemble_model = Model(model_input, output_of_the_model)

# %%
ensemble_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  model1 (Sequential)            (None, 4)            23341028    ['input_1[0][0]']
#
#  model2 (Sequential)            (None, 4)            5745028     ['input_1[0][0]']
#
#  average (Average)              (None, 4)            0           ['model1[0][0]',
#                                                                   'model2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 4)           16          ['average[0][0]']
#  alization)
#
#  dense (Dense)                  (None, 128)          640         ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 128)         512         ['dense[0][0]']
#  rmalization)
#
#  dropout (Dropout)              (None, 128)          0           ['batch_normalization_1[0][0]']
#
#  dense_1 (Dense)                (None, 32)           4128        ['dropout[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32)          128         ['dense_1[0][0]']
#  rmalization)
#
#  dropout_1 (Dropout)            (None, 32)           0           ['batch_normalization_2[0][0]']
#
#  dense_2 (Dense)                (None, 4)            132         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 29,091,612
# Trainable params: 8,929,300
# Non-trainable params: 20,162,312
# __________________________________________________________________________________________________

# %%
ensemble_model.compile(loss=CategoricalCrossentropy(), optimizer=Adam(learning_rate=0.00001), metrics=['accuracy'])

# %%
ensemble_model.fit(train_image_gen, validation_data=test_image_gen, epochs=30, callbacks=[early_stop_loss, early_stop_val_loss])
# Out:
# Epoch 1/30
# 325/325 [==============================] - 120s 310ms/step - loss: 1.9883 - accuracy: 0.2625 - val_loss: 1.4055 - val_accuracy: 0.4692
# Epoch 2/30
# 325/325 [==============================] - 93s 285ms/step - loss: 1.5972 - accuracy: 0.3621 - val_loss: 0.9444 - val_accuracy: 0.5933
# Epoch 3/30
# 325/325 [==============================] - 92s 283ms/step - loss: 1.3244 - accuracy: 0.4546 - val_loss: 0.7493 - val_accuracy: 0.7725
# Epoch 4/30
# 325/325 [==============================] - 93s 285ms/step - loss: 1.1087 - accuracy: 0.5625 - val_loss: 0.6007 - val_accuracy: 0.8350
# Epoch 5/30
# 325/325 [==============================] - 92s 284ms/step - loss: 0.9628 - accuracy: 0.6223 - val_loss: 0.5018 - val_accuracy: 0.8692
# Epoch 6/30
# 325/325 [==============================] - 92s 281ms/step - loss: 0.8495 - accuracy: 0.6765 - val_loss: 0.4898 - val_accuracy: 0.8533
# Epoch 7/30
# 325/325 [==============================] - 92s 282ms/step - loss: 0.7894 - accuracy: 0.7188 - val_loss: 0.4160 - val_accuracy: 0.8767
# Epoch 8/30
# 325/325 [==============================] - 92s 284ms/step - loss: 0.7303 - accuracy: 0.7467 - val_loss: 0.4112 - val_accuracy: 0.8808
# Epoch 9/30
# 325/325 [==============================] - 92s 283ms/step - loss: 0.6981 - accuracy: 0.7527 - val_loss: 0.3933 - val_accuracy: 0.8825
# Epoch 10/30
# 325/325 [==============================] - 93s 284ms/step - loss: 0.6577 - accuracy: 0.7817 - val_loss: 0.3830 - val_accuracy: 0.8833
# Epoch 11/30
# 325/325 [==============================] - 93s 286ms/step - loss: 0.6296 - accuracy: 0.7960 - val_loss: 0.3507 - val_accuracy: 0.8833
# Epoch 12/30
# 325/325 [==============================] - 92s 283ms/step - loss: 0.6131 - accuracy: 0.7981 - val_loss: 0.3587 - val_accuracy: 0.8883
# Epoch 13/30
# 325/325 [==============================] - 92s 281ms/step - loss: 0.5925 - accuracy: 0.8123 - val_loss: 0.3475 - val_accuracy: 0.8908
# Epoch 14/30
# 325/325 [==============================] - 92s 284ms/step - loss: 0.5993 - accuracy: 0.8071 - val_loss: 0.3110 - val_accuracy: 0.8967
# Epoch 15/30
# 325/325 [==============================] - 92s 282ms/step - loss: 0.5652 - accuracy: 0.8217 - val_loss: 0.3413 - val_accuracy: 0.8867
# Epoch 16/30
# 325/325 [==============================] - 92s 282ms/step - loss: 0.5214 - accuracy: 0.8360 - val_loss: 0.3218 - val_accuracy: 0.8983

# %%
history_df = pd.DataFrame(ensemble_model.history.history)

# %%
history_df[['loss', 'val_loss']].plot()
# Out:
# <Axes: >

# %%
history_df[['accuracy', 'val_accuracy']].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Evaluating the model

# %%
ensemble_model.evaluate(train_image_gen)[1]
# Out:
# 325/325 [==============================] - 75s 229ms/step - loss: 0.2075 - accuracy: 0.9396
# 0.9396153688430786

# %%
ensemble_model.evaluate(test_image_gen)[1]
# Out:
# 75/75 [==============================] - 17s 227ms/step - loss: 0.3235 - accuracy: 0.8850
# 0.8849999904632568

# %% [markdown]
# ## Predicting on a sample image

# %%
sample_img_load = image.load_img('./brain_dataset/test/pituitary/Te-piTr_0003.jpg', target_size=correct_image_shape)

# %%
sample_img_load
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
sample_img_to_arr = image.img_to_array(sample_img_load)

# %%
sample_img_to_arr = preprocess_input(sample_img_to_arr)

# %%
sample_img_to_arr_expand_dim = np.expand_dims(sample_img_to_arr, 0)

# %%
prediction = ensemble_model.predict(sample_img_to_arr_expand_dim)[0]
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
pred_result = np.argmax(prediction)

# %%
class_names = ['glioma', 'meningioma', 'no tumor', 'pituitary']

# %%
pred_final_result = class_names[pred_result]

# %%
pred_final_result
# Out:
# 'pituitary'
