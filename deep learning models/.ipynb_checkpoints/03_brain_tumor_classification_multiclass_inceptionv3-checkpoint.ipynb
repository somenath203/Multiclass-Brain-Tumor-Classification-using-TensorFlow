# %% [markdown]
# ## Importing the necessary libraries

# %%
import os
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.image import imread
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.optimizers import Adam 
import tensorflow_hub as hub
from tensorflow.keras.preprocessing import image

# %% [markdown]
# ## Getting the path of the training and testing data of the brain tumor dataset

# %%
dataset_directory_location = 'brain_dataset'

# %%
os.listdir(dataset_directory_location)
# Out:
# ['test', 'train']

# %%
train_dataset_location = os.path.join(dataset_directory_location, 'train')
test_dataset_location = os.path.join(dataset_directory_location, 'test')

# %%
os.listdir(train_dataset_location)
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
os.listdir(test_dataset_location)
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %% [markdown]
# ## Viewing a brain image

# %%
brain_img_glicoma = os.path.join(train_dataset_location, 'glioma')

# %%
os.listdir(brain_img_glicoma)[:1]
# Out:
# ['Tr-gl_0010.jpg']

# %%
brain_img_glicoma_read = imread(os.path.join(brain_img_glicoma, 'Tr-gl_0010.jpg'))

# %%
plt.imshow(brain_img_glicoma_read)

# %%
brain_img_glicoma_read.shape
# Out:
# (512, 512, 3)

# %% [markdown]
# ## Defining the correct shape of the image

# %%
correct_image_shape = (128, 128, 3)

# %% [markdown]
# ## Defining the ImageGenerator and performing Data Augmentation

# %%
image_gen = ImageDataGenerator(rotation_range=20, 
                               width_shift_range=0.1, 
                               height_shift_range=0.1, 
                               shear_range=0.1, 
                               zoom_range=0.1, 
                               horizontal_flip=True, 
                               fill_mode='nearest',
                               rescale=1./255)

# %%
train_image_gen = image_gen.flow_from_directory(train_dataset_location, 
                                                target_size=correct_image_shape[:2], 
                                                color_mode='rgb', 
                                                batch_size=16, 
                                                class_mode='categorical')

test_image_gen = image_gen.flow_from_directory(test_dataset_location, 
                                                target_size=correct_image_shape[:2], 
                                                color_mode='rgb', 
                                                batch_size=16, 
                                                class_mode='categorical')
# Out:
# Found 5200 images belonging to 4 classes.
# Found 1200 images belonging to 4 classes.

# %% [markdown]
# ## Defining the early stop

# %%
early_stop_loss = EarlyStopping(monitor='loss', patience=2)
early_stop_val_loss = EarlyStopping(monitor='val_loss', patience=2)

# %% [markdown]
# ## Creating and training the model

# %%
model = Sequential()

# %%
get_inception_v3_pretrained_model = "https://www.kaggle.com/models/google/inception-v3/frameworks/TensorFlow2/variations/classification/versions/2"

# %%
inception_v3_pretrained_model = hub.KerasLayer(get_inception_v3_pretrained_model, input_shape=correct_image_shape, trainable=False)

# %%
model.add(inception_v3_pretrained_model)

model.add(BatchNormalization())

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())

model.add(Dropout(0.3))

model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())

model.add(Dropout(0.3))

model.add(Dense(4, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 1001)              23853833
#
#  batch_normalization (BatchN  (None, 1001)             4004
#  ormalization)
#
#  dense (Dense)               (None, 128)               128256
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 32)                4128
#
#  batch_normalization_2 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 23,990,993
# Trainable params: 134,838
# Non-trainable params: 23,856,155
# _________________________________________________________________

# %%
model.compile(loss=CategoricalCrossentropy(), optimizer=Adam(learning_rate=0.00001), metrics=['accuracy'])

# %%
model.fit(train_image_gen, validation_data=test_image_gen, epochs=30, callbacks=[early_stop_loss, early_stop_val_loss])
# Out:
# Epoch 1/30
# 325/325 [==============================] - 56s 135ms/step - loss: 2.0102 - accuracy: 0.3004 - val_loss: 1.5407 - val_accuracy: 0.3508
# Epoch 2/30
# 325/325 [==============================] - 41s 127ms/step - loss: 1.7284 - accuracy: 0.3627 - val_loss: 1.3286 - val_accuracy: 0.4467
# Epoch 3/30
# 325/325 [==============================] - 41s 127ms/step - loss: 1.5116 - accuracy: 0.4342 - val_loss: 1.1867 - val_accuracy: 0.5067
# Epoch 4/30
# 325/325 [==============================] - 43s 133ms/step - loss: 1.3949 - accuracy: 0.4748 - val_loss: 1.0304 - val_accuracy: 0.5633
# Epoch 5/30
# 325/325 [==============================] - 40s 124ms/step - loss: 1.3009 - accuracy: 0.5015 - val_loss: 0.9538 - val_accuracy: 0.6258
# Epoch 6/30
# 325/325 [==============================] - 42s 128ms/step - loss: 1.2079 - accuracy: 0.5308 - val_loss: 0.9449 - val_accuracy: 0.6225
# Epoch 7/30
# 325/325 [==============================] - 41s 126ms/step - loss: 1.1993 - accuracy: 0.5469 - val_loss: 0.9029 - val_accuracy: 0.6492
# Epoch 8/30
# 325/325 [==============================] - 41s 127ms/step - loss: 1.0995 - accuracy: 0.5710 - val_loss: 0.8722 - val_accuracy: 0.6475
# Epoch 9/30
# 325/325 [==============================] - 41s 126ms/step - loss: 1.0778 - accuracy: 0.5804 - val_loss: 0.8279 - val_accuracy: 0.6783
# Epoch 10/30
# 325/325 [==============================] - 41s 127ms/step - loss: 1.0620 - accuracy: 0.5956 - val_loss: 0.8160 - val_accuracy: 0.6783
# Epoch 11/30
# 325/325 [==============================] - 41s 126ms/step - loss: 1.0090 - accuracy: 0.6148 - val_loss: 0.8016 - val_accuracy: 0.6858
# Epoch 12/30
# 325/325 [==============================] - 41s 127ms/step - loss: 0.9867 - accuracy: 0.6265 - val_loss: 0.8025 - val_accuracy: 0.6908
# Epoch 13/30
# 325/325 [==============================] - 41s 126ms/step - loss: 0.9897 - accuracy: 0.6304 - val_loss: 0.7446 - val_accuracy: 0.7042
# Epoch 14/30
# 325/325 [==============================] - 42s 128ms/step - loss: 0.9421 - accuracy: 0.6427 - val_loss: 0.7528 - val_accuracy: 0.7092
# Epoch 15/30
# 325/325 [==============================] - 41s 126ms/step - loss: 0.9370 - accuracy: 0.6529 - val_loss: 0.7330 - val_accuracy: 0.7042
# Epoch 16/30
# 325/325 [==============================] - 42s 128ms/step - loss: 0.9162 - accuracy: 0.6523 - val_loss: 0.7359 - val_accuracy: 0.7075
# Epoch 17/30
# 325/325 [==============================] - 41s 126ms/step - loss: 0.9129 - accuracy: 0.6498 - val_loss: 0.6937 - val_accuracy: 0.7267
# Epoch 18/30
# 325/325 [==============================] - 41s 125ms/step - loss: 0.8976 - accuracy: 0.6594 - val_loss: 0.7176 - val_accuracy: 0.7283
# Epoch 19/30
# 325/325 [==============================] - 41s 126ms/step - loss: 0.8962 - accuracy: 0.6579 - val_loss: 0.6998 - val_accuracy: 0.7200

# %%
history_df = pd.DataFrame(model.history.history)

# %%
history_df[['loss', 'val_loss']].plot()
# Out:
# <Axes: >

# %%
history_df[['accuracy', 'val_accuracy']].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Evaluating the model

# %%
model.evaluate(train_image_gen)[1]
# Out:
# 325/325 [==============================] - 34s 104ms/step - loss: 0.6099 - accuracy: 0.7652
# 0.7651923298835754

# %%
model.evaluate(test_image_gen)[1]
# Out:
# 75/75 [==============================] - 7s 99ms/step - loss: 0.6975 - accuracy: 0.7242
# 0.7241666913032532

# %% [markdown]
# ## Predicting on a sample image

# %%
sample_img_load = image.load_img('./brain_dataset/test/pituitary/Te-piTr_0003.jpg', target_size=correct_image_shape)

# %%
sample_img_load
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
sample_img_to_arr = image.img_to_array(sample_img_load)

# %%
sample_img_to_arr = image.img_to_array(sample_img_load) / 255

# %%
sample_img_to_arr_expand_dim = np.expand_dims(sample_img_to_arr, 0)

# %%
prediction = model.predict(sample_img_to_arr_expand_dim)[0]
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
pred_result = np.argmax(prediction)

# %%
class_names = ['glioma', 'meningioma', 'no tumor', 'pituitary']

# %%
pred_final_result = class_names[pred_result]

# %%
pred_final_result
# Out:
# 'pituitary'
