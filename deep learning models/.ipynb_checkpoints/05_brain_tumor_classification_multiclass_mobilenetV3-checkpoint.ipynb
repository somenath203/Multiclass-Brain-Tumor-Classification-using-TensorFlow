# %% [markdown]
# ## Importing the necessary libraries

# %%
import os
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.image import imread
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.optimizers import Adam 
import tensorflow_hub as hub
from tensorflow.keras.preprocessing import image

# %% [markdown]
# ## Getting the path of the training and testing data of the brain tumor dataset

# %%
dataset_directory_location = 'brain_dataset'

# %%
os.listdir(dataset_directory_location)
# Out:
# ['test', 'train']

# %%
train_dataset_location = os.path.join(dataset_directory_location, 'train')
test_dataset_location = os.path.join(dataset_directory_location, 'test')

# %%
os.listdir(train_dataset_location)
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
os.listdir(test_dataset_location)
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %% [markdown]
# ## Viewing a brain image

# %%
brain_img_glicoma = os.path.join(train_dataset_location, 'glioma')

# %%
os.listdir(brain_img_glicoma)[:1]
# Out:
# ['Tr-gl_0010.jpg']

# %%
brain_img_glicoma_read = imread(os.path.join(brain_img_glicoma, 'Tr-gl_0010.jpg'))

# %%
plt.imshow(brain_img_glicoma_read)

# %%
brain_img_glicoma_read.shape
# Out:
# (512, 512, 3)

# %% [markdown]
# ## Defining the correct shape of the image

# %%
correct_image_shape = (224, 224, 3)

# %% [markdown]
# ## Defining the ImageGenerator and performing Data Augmentation

# %%
image_gen = ImageDataGenerator(rotation_range=20, 
                               width_shift_range=0.1, 
                               height_shift_range=0.1, 
                               shear_range=0.1, 
                               zoom_range=0.1, 
                               horizontal_flip=True, 
                               fill_mode='nearest',
                               rescale=1./255)

# %%
train_image_gen = image_gen.flow_from_directory(train_dataset_location, 
                                                target_size=correct_image_shape[:2], 
                                                color_mode='rgb', 
                                                batch_size=16, 
                                                class_mode='categorical')

test_image_gen = image_gen.flow_from_directory(test_dataset_location, 
                                                target_size=correct_image_shape[:2], 
                                                color_mode='rgb', 
                                                batch_size=16, 
                                                class_mode='categorical')
# Out:
# Found 5200 images belonging to 4 classes.
# Found 1200 images belonging to 4 classes.

# %% [markdown]
# ## Defining the early stop

# %%
early_stop_loss = EarlyStopping(monitor='loss', patience=2)
early_stop_val_loss = EarlyStopping(monitor='val_loss', patience=2)

# %% [markdown]
# ## Creating and training the model

# %%
model = Sequential()

# %%
get_mobilenet_v3_pretrained_model = "https://www.kaggle.com/models/google/mobilenet-v3/frameworks/TensorFlow2/variations/small-075-224-classification/versions/1"

# %%
mobilenet_v3_pretrained_model = hub.KerasLayer(get_mobilenet_v3_pretrained_model, input_shape=correct_image_shape, trainable=False)

# %%
model.add(mobilenet_v3_pretrained_model)

model.add(BatchNormalization())

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())

model.add(Dropout(0.3))

model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())

model.add(Dropout(0.3))

model.add(Dense(4, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 1001)              2052577
#
#  batch_normalization (BatchN  (None, 1001)             4004
#  ormalization)
#
#  dense (Dense)               (None, 128)               128256
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 32)                4128
#
#  batch_normalization_2 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 2,189,737
# Trainable params: 134,838
# Non-trainable params: 2,054,899
# _________________________________________________________________

# %%
model.compile(loss=CategoricalCrossentropy(), optimizer=Adam(learning_rate=0.00001), metrics=['accuracy'])

# %%
model.fit(train_image_gen, validation_data=test_image_gen, epochs=30, callbacks=[early_stop_loss, early_stop_val_loss])
# Out:
# Epoch 1/30
# 325/325 [==============================] - 101s 282ms/step - loss: 1.9551 - accuracy: 0.2956 - val_loss: 1.3814 - val_accuracy: 0.4308
# Epoch 2/30
# 325/325 [==============================] - 90s 276ms/step - loss: 1.5073 - accuracy: 0.4246 - val_loss: 1.0732 - val_accuracy: 0.5683
# Epoch 3/30
# 325/325 [==============================] - 90s 277ms/step - loss: 1.2419 - accuracy: 0.5088 - val_loss: 0.9505 - val_accuracy: 0.6300
# Epoch 4/30
# 325/325 [==============================] - 92s 282ms/step - loss: 1.0716 - accuracy: 0.5892 - val_loss: 0.8267 - val_accuracy: 0.6950
# Epoch 5/30
# 325/325 [==============================] - 89s 275ms/step - loss: 0.9699 - accuracy: 0.6215 - val_loss: 0.7477 - val_accuracy: 0.7275
# Epoch 6/30
# 325/325 [==============================] - 90s 276ms/step - loss: 0.9079 - accuracy: 0.6488 - val_loss: 0.7301 - val_accuracy: 0.7475
# Epoch 7/30
# 325/325 [==============================] - 95s 292ms/step - loss: 0.8432 - accuracy: 0.6785 - val_loss: 0.6909 - val_accuracy: 0.7550
# Epoch 8/30
# 325/325 [==============================] - 90s 277ms/step - loss: 0.7893 - accuracy: 0.6962 - val_loss: 0.6529 - val_accuracy: 0.7625
# Epoch 9/30
# 325/325 [==============================] - 91s 279ms/step - loss: 0.7491 - accuracy: 0.7200 - val_loss: 0.6420 - val_accuracy: 0.7625
# Epoch 10/30
# 325/325 [==============================] - 108s 333ms/step - loss: 0.7343 - accuracy: 0.7237 - val_loss: 0.6090 - val_accuracy: 0.7717
# Epoch 11/30
# 325/325 [==============================] - 97s 299ms/step - loss: 0.7076 - accuracy: 0.7304 - val_loss: 0.5973 - val_accuracy: 0.7883
# Epoch 12/30
# 325/325 [==============================] - 89s 274ms/step - loss: 0.6715 - accuracy: 0.7515 - val_loss: 0.5793 - val_accuracy: 0.7867
# Epoch 13/30
# 325/325 [==============================] - 89s 274ms/step - loss: 0.6446 - accuracy: 0.7579 - val_loss: 0.5579 - val_accuracy: 0.8067
# Epoch 14/30
# 325/325 [==============================] - 91s 281ms/step - loss: 0.6320 - accuracy: 0.7644 - val_loss: 0.5663 - val_accuracy: 0.7958
# Epoch 15/30
# 325/325 [==============================] - 89s 274ms/step - loss: 0.6255 - accuracy: 0.7810 - val_loss: 0.5404 - val_accuracy: 0.7958
# Epoch 16/30
# 325/325 [==============================] - 89s 275ms/step - loss: 0.6140 - accuracy: 0.7737 - val_loss: 0.5500 - val_accuracy: 0.7917
# Epoch 17/30
# 325/325 [==============================] - 90s 276ms/step - loss: 0.6019 - accuracy: 0.7740 - val_loss: 0.5222 - val_accuracy: 0.8042
# Epoch 18/30
# 325/325 [==============================] - 90s 278ms/step - loss: 0.6212 - accuracy: 0.7669 - val_loss: 0.5266 - val_accuracy: 0.7992
# Epoch 19/30
# 325/325 [==============================] - 90s 276ms/step - loss: 0.5839 - accuracy: 0.7869 - val_loss: 0.4932 - val_accuracy: 0.8200
# Epoch 20/30
# 325/325 [==============================] - 90s 276ms/step - loss: 0.5902 - accuracy: 0.7794 - val_loss: 0.4988 - val_accuracy: 0.8175
# Epoch 21/30
# 325/325 [==============================] - 89s 274ms/step - loss: 0.5506 - accuracy: 0.7971 - val_loss: 0.5097 - val_accuracy: 0.8125

# %%
history_df = pd.DataFrame(model.history.history)

# %%
history_df[['loss', 'val_loss']].plot()
# Out:
# <Axes: >

# %%
history_df[['accuracy', 'val_accuracy']].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Evaluating the model

# %%
model.evaluate(train_image_gen)[1]
# Out:
# 325/325 [==============================] - 73s 223ms/step - loss: 0.3524 - accuracy: 0.8767
# 0.876730740070343

# %%
model.evaluate(test_image_gen)[1]
# Out:
# 75/75 [==============================] - 17s 221ms/step - loss: 0.4894 - accuracy: 0.8192
# 0.8191666603088379

# %% [markdown]
# ## Predicting on a sample image

# %%
sample_img_load = image.load_img('./brain_dataset/test/pituitary/Te-piTr_0003.jpg', target_size=correct_image_shape)

# %%
sample_img_load
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
sample_img_to_arr = image.img_to_array(sample_img_load)

# %%
sample_img_to_arr = image.img_to_array(sample_img_load) / 255

# %%
sample_img_to_arr_expand_dim = np.expand_dims(sample_img_to_arr, 0)

# %%
prediction = model.predict(sample_img_to_arr_expand_dim)[0]
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
pred_result = np.argmax(prediction)

# %%
class_names = ['glioma', 'meningioma', 'no tumor', 'pituitary']

# %%
pred_final_result = class_names[pred_result]

# %%
pred_final_result
# Out:
# 'pituitary'
