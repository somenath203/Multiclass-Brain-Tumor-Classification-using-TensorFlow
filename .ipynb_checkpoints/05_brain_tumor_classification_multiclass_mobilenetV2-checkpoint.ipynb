# %% [markdown]
# ## Importing the necessary libraries

# %%
import os
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.image import imread
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, save_model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.optimizers import Adam 
import tensorflow_hub as hub
from tensorflow.keras.preprocessing import image

# %% [markdown]
# ## Getting the path of the training and testing data of the brain tumor dataset

# %%
dataset_directory_location = 'brain_dataset'

# %%
os.listdir(dataset_directory_location)
# Out:
# ['test', 'train']

# %%
train_dataset_location = os.path.join(dataset_directory_location, 'train')
test_dataset_location = os.path.join(dataset_directory_location, 'test')

# %%
os.listdir(train_dataset_location)
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
os.listdir(test_dataset_location)
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %% [markdown]
# ## Viewing a brain image

# %%
brain_img_glicoma = os.path.join(train_dataset_location, 'glioma')

# %%
os.listdir(brain_img_glicoma)[:1]
# Out:
# ['Tr-gl_0010.jpg']

# %%
brain_img_glicoma_read = imread(os.path.join(brain_img_glicoma, 'Tr-gl_0010.jpg'))

# %%
plt.imshow(brain_img_glicoma_read)

# %%
brain_img_glicoma_read.shape
# Out:
# (512, 512, 3)

# %% [markdown]
# ## Defining the correct shape of the image

# %%
correct_image_shape = (128, 128, 3)

# %% [markdown]
# ## Defining the ImageGenerator and performing Data Augmentation

# %%
image_gen = ImageDataGenerator(rotation_range=20, 
                               width_shift_range=0.1, 
                               height_shift_range=0.1, 
                               shear_range=0.1, 
                               zoom_range=0.1, 
                               horizontal_flip=True, 
                               fill_mode='nearest',
                               rescale=1./255)

# %%
train_image_gen = image_gen.flow_from_directory(train_dataset_location, 
                                                target_size=correct_image_shape[:2], 
                                                color_mode='rgb', 
                                                batch_size=16, 
                                                class_mode='categorical')

test_image_gen = image_gen.flow_from_directory(test_dataset_location, 
                                                target_size=correct_image_shape[:2], 
                                                color_mode='rgb', 
                                                batch_size=16, 
                                                class_mode='categorical')
# Out:
# Found 5200 images belonging to 4 classes.
# Found 1200 images belonging to 4 classes.

# %% [markdown]
# ## Defining the early stop

# %%
early_stop_loss = EarlyStopping(monitor='loss', patience=2)
early_stop_val_loss = EarlyStopping(monitor='val_loss', patience=2)

# %% [markdown]
# ## Creating and training the model

# %%
model = Sequential()

# %%
get_mobilenet_v2_pretrained_model = "https://www.kaggle.com/models/google/mobilenet-v2/frameworks/TensorFlow2/variations/035-128-classification/versions/2"

# %%
mobilenet_v2_pretrained_model = hub.KerasLayer(get_mobilenet_v2_pretrained_model, input_shape=correct_image_shape, trainable=False)

# %%
model.add(mobilenet_v2_pretrained_model)

model.add(BatchNormalization())

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())

model.add(Dropout(0.3))

model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())

model.add(Dropout(0.3))

model.add(Dense(4, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 1001)              1692489
#
#  batch_normalization (BatchN  (None, 1001)             4004
#  ormalization)
#
#  dense (Dense)               (None, 128)               128256
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 32)                4128
#
#  batch_normalization_2 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 1,829,649
# Trainable params: 134,838
# Non-trainable params: 1,694,811
# _________________________________________________________________

# %%
model.compile(loss=CategoricalCrossentropy(), optimizer=Adam(learning_rate=0.00001), metrics=['accuracy'])

# %%
model.fit(train_image_gen, validation_data=test_image_gen, epochs=30, callbacks=[early_stop_loss, early_stop_val_loss])
# Out:
# Epoch 1/30
# 325/325 [==============================] - 51s 129ms/step - loss: 1.7453 - accuracy: 0.3479 - val_loss: 1.2066 - val_accuracy: 0.4742
# Epoch 2/30
# 325/325 [==============================] - 40s 124ms/step - loss: 1.4315 - accuracy: 0.4477 - val_loss: 1.0068 - val_accuracy: 0.5817
# Epoch 3/30
# 325/325 [==============================] - 41s 126ms/step - loss: 1.2328 - accuracy: 0.5160 - val_loss: 0.8602 - val_accuracy: 0.6517
# Epoch 4/30
# 325/325 [==============================] - 41s 125ms/step - loss: 1.1274 - accuracy: 0.5604 - val_loss: 0.8146 - val_accuracy: 0.6925
# Epoch 5/30
# 325/325 [==============================] - 40s 124ms/step - loss: 1.0493 - accuracy: 0.5862 - val_loss: 0.7605 - val_accuracy: 0.7217
# Epoch 6/30
# 325/325 [==============================] - 40s 124ms/step - loss: 0.9533 - accuracy: 0.6337 - val_loss: 0.7292 - val_accuracy: 0.7225
# Epoch 7/30
# 325/325 [==============================] - 40s 124ms/step - loss: 0.8966 - accuracy: 0.6594 - val_loss: 0.6872 - val_accuracy: 0.7450
# Epoch 8/30
# 325/325 [==============================] - 41s 125ms/step - loss: 0.8676 - accuracy: 0.6713 - val_loss: 0.6722 - val_accuracy: 0.7558
# Epoch 9/30
# 325/325 [==============================] - 40s 124ms/step - loss: 0.8582 - accuracy: 0.6804 - val_loss: 0.6516 - val_accuracy: 0.7625
# Epoch 10/30
# 325/325 [==============================] - 41s 126ms/step - loss: 0.8135 - accuracy: 0.6996 - val_loss: 0.6449 - val_accuracy: 0.7692
# Epoch 11/30
# 325/325 [==============================] - 41s 125ms/step - loss: 0.7841 - accuracy: 0.7098 - val_loss: 0.6079 - val_accuracy: 0.7842
# Epoch 12/30
# 325/325 [==============================] - 41s 126ms/step - loss: 0.7836 - accuracy: 0.7056 - val_loss: 0.5941 - val_accuracy: 0.7858
# Epoch 13/30
# 325/325 [==============================] - 42s 129ms/step - loss: 0.7514 - accuracy: 0.7175 - val_loss: 0.5781 - val_accuracy: 0.7992
# Epoch 14/30
# 325/325 [==============================] - 41s 125ms/step - loss: 0.7314 - accuracy: 0.7242 - val_loss: 0.5697 - val_accuracy: 0.7875
# Epoch 15/30
# 325/325 [==============================] - 40s 124ms/step - loss: 0.7332 - accuracy: 0.7250 - val_loss: 0.5540 - val_accuracy: 0.8042
# Epoch 16/30
# 325/325 [==============================] - 41s 125ms/step - loss: 0.7407 - accuracy: 0.7312 - val_loss: 0.5538 - val_accuracy: 0.7975

# %%
history_df = pd.DataFrame(model.history.history)

# %%
history_df[['loss', 'val_loss']].plot()
# Out:
# <Axes: >

# %%
history_df[['accuracy', 'val_accuracy']].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Evaluating the model

# %%
model.evaluate(train_image_gen)[1]
# Out:
# 325/325 [==============================] - 33s 101ms/step - loss: 0.4583 - accuracy: 0.8388
# 0.8388461470603943

# %%
model.evaluate(test_image_gen)[1]
# Out:
# 75/75 [==============================] - 8s 100ms/step - loss: 0.5605 - accuracy: 0.8008
# 0.8008333444595337

# %% [markdown]
# ## Predicting on a sample image

# %%
sample_img_load = image.load_img('./brain_dataset/test/pituitary/Te-piTr_0003.jpg', target_size=correct_image_shape)

# %%
sample_img_load
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
sample_img_to_arr = image.img_to_array(sample_img_load)

# %%
sample_img_to_arr = image.img_to_array(sample_img_load) / 255

# %%
sample_img_to_arr_expand_dim = np.expand_dims(sample_img_to_arr, 0)

# %%
prediction = model.predict(sample_img_to_arr_expand_dim)[0]
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
pred_result = np.argmax(prediction)

# %%
class_names = ['glioma', 'meningioma', 'no tumor', 'pituitary']

# %%
pred_final_result = class_names[pred_result]

# %%
pred_final_result
# Out:
# 'pituitary'

# %%
save_model(model, 'mobilenetv2_model')
# Out:
# INFO:tensorflow:Assets written to: mobilenetv2_model\assets
# INFO:tensorflow:Assets written to: mobilenetv2_model\assets
